# %%
# Exercise 1: Regression - Optimize
"""
Exercise: Setting up optimization for a regression neural network

Neural Network Architecture:
- Input Layer: 5 features
- Hidden Layer 1: 8 neurons with sigmoid activation
- Hidden Layer 2: 4 neurons with sigmoid activation
- Output Layer: 1 neuron with LINEAR activation (key for regression!)

The linear activation in the output layer allows the network to predict
continuous values (any real number), which is essential for regression tasks.
"""

from tensorflow import keras
from keras.layers import Dense

# Build the regression neural network
model = keras.Sequential()
model.add(Dense(8, input_shape=(5,), activation='sigmoid'))
model.add(Dense(4, activation='sigmoid'))
model.add(Dense(1, activation='linear'))  # Linear activation for regression!


# SOLUTION 1: Using Mean Squared Error (MSE) - Most Common for Regression
model.compile(
    optimizer='adam',
    loss='mse',           # TODO1: Mean Squared Error
    metrics=['mae']       # TODO2: Mean Absolute Error
)

print("✓ Model compiled successfully with MSE loss and MAE metric!")
print("\nModel Summary:")
model.summary()

# Alternative 2: Using MAE as loss (good when you have outliers)
print("\n2. Using MAE as loss (more robust to outliers):")
print("""
model.compile(
    optimizer='adam',
    loss='mae',              # Mean Absolute Error as loss
    metrics=['mse']          # MSE as evaluation metric
)
""")
# Out:
# ✓ Model compiled successfully with MSE loss and MAE metric!
#
# Model Summary:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 8)              │            48 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 89 (356.00 B)
#  Trainable params: 89 (356.00 B)
#  Non-trainable params: 0 (0.00 B)
# 2. Using MAE as loss (more robust to outliers):
#
# model.compile(
# ...

# %%
# Exercise 2: Regression example
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

columns = ["mpg", "cylinders", "displacement", "horsepower", "weight",
           "acceleration", "model year", "origin", "car name"]

df = pd.read_csv("auto-mpg.csv", na_values="?", comment="\t",
                 sep=",", skipinitialspace=True)
# Drop missing values
df = df.dropna()
print(df.head())
print(df.shape)
print(df.dtypes)
# Drop non-needed columns
df = df.drop(columns=["model year", "origin", "car name"])

# Features and target
X = df.drop(columns=["mpg"])
y = df["mpg"]

# Train/test split WITHOUT shuffling
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, shuffle=False
)

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 3. BUILD THE MODEL (2 hidden layers)
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1)   # regression output
])

model.compile(
    optimizer=Adam(0.001),
    loss='mean_squared_error',
    metrics=['mean_absolute_error']
)

# 4. TRAIN
history = model.fit(
    X_train_scaled, y_train,
    epochs=200,   # increase if MAE is too high
    batch_size=16,
    verbose=1
)

# 5. EVALUATE ON SCALED TEST SET
loss, mae = model.evaluate(X_test_scaled, y_test, verbose=0)

print(f"Test MAE: {mae:.3f}")
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino
# (392, 9)
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object
# Epoch 1/200
# ...

# %%
# Exercise 3: Multi classification - Softmax
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Number of input features
input_dim = 5        # as required
num_classes = 5      # apples, bears, candies, eggs, dogs

model = Sequential()

# Hidden layer 1
model.add(Dense(16, activation="sigmoid", input_dim=input_dim))

# Hidden layer 2
model.add(Dense(8, activation="sigmoid"))

# Output layer (multi-class)
model.add(Dense(num_classes, activation="softmax"))

# Print summary
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │            96 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 5)              │            45 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 277 (1.08 KB)
#  Trainable params: 277 (1.08 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Exercise 4: Multi classification - Optimize
model.compile(loss='categorical_crossentropy',
              optimizer='adam',                
              metrics=['accuracy'])

# %%
# Exercise 5 Multi classification example
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelBinarizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

data = load_iris()
X = data.data       # features
y = data.target     # class labels (0,1,2)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=1
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

lb = LabelBinarizer()
y_train_oh = lb.fit_transform(y_train)
y_test_oh = lb.transform(y_test)

model = Sequential()
model.add(Dense(16, activation='sigmoid', input_dim=4))
model.add(Dense(3, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    X_train_scaled,
    y_train_oh,
    epochs=100,
    batch_size=8,
    verbose=1
)

loss, acc = model.evaluate(X_test_scaled, y_test_oh, verbose=0)
print("Test accuracy:", acc)

predictions = model.predict(X_test_scaled)
predicted_classes = np.argmax(predictions, axis=1)

print(predicted_classes)
print(list(y_test))
# Out:
# Epoch 1/100
# /home/shaokoth/keras2/ex00/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3083 - loss: 1.3214
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3083 - loss: 1.2289
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3083 - loss: 1.1517
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3083 - loss: 1.0846
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3583 - loss: 1.0338
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4500 - loss: 0.9856
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5083 - loss: 0.9489
# Epoch 8/100
# ...
